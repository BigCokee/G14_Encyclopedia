# %% [markdown]
# ## About Encyclopaedia Britannica - Seventh Edition

# %% [markdown]
# Data format: digitised text
#
# Data creation process: Optical Character Recognition (OCR)
#
# Data source: https://data.nls.uk/

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
conda install -c anaconda nltk
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge wordcloud
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import wordnet
from nltk.tag import pos_tag
from nltk.text import Text
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud, STOPWORDS
import json
# Out:
# [nltk_data] Downloading package punkt to /Users/hekeren/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/hekeren/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hekeren/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/hekeren/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Read the Encyclopedia Britannica CSV index file
encyclopaedia = pd.read_csv("encyclopaediaBritannica-inventory.csv", header=None)
encyclopaedia.columns = ['file','volume']
#print the seventh edition of encyclopaedia
#not include general index of seventh edition
sevenths = encyclopaedia[151:172]
#reset index
sevenths = sevenths.reset_index(drop=True)
#print sevenths
sevenths
# Out:
#              file                                             volume
# 0   192984258.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 1   192984259.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 2   193057500.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 3   193108322.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 4   193696083.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 5   193322690.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 6   193819043.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 7   193322688.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 8   193696084.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 9   193469090.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 10  193638940.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 11  192693199.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 12  193108323.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 13  193322689.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 14  193819044.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 15  194474782.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 16  193469091.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 17  193469092.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 18  193057501.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 19  193913444.txt  Encyclopaedia Britannica - Seventh edition, Vo...
# 20  193819045.txt  Encyclopaedia Britannica - Seventh edition, Vo...

# %% [markdown]
# ## Clean

# %% [markdown]
# The seventh edition of the Encyclopaedia Britannica has 21 volumes, in addition to the index, which contain a very large number of words. And due to OCR, there are many errors. I cleaned up the data.
#
# First I extracted all the English words of the 7th edition.

# %%
#Regular expressions represent words
english_words = re.compile("[a-zA-Z]+")

#Recognize English words 
def englishwords(some_strings):
    all_english_words = []
    for i in some_strings:
        matches = english_words.match(i)
        #fail to match
        if matches != None:             
            yesisenglish = matches.group()
            if wordnet.synsets(yesisenglish): 
                #https://blog.csdn.net/ltochange/article/details/117431933?ops_request_misc=%257B%2522request%255Fid%2522%253A%2522163665155816780274126867%2522%252C%2522scm%2522%253A%252220140713.130102334.pc%255Fall.%2522%257D&request_id=163665155816780274126867&biz_id=0&utm_medium=distribute.pc_search_result.none-task-blog-2~all~first_rank_ecpm_v1~rank_v31_ecpm-6-117431933.first_rank_v2_pc_rank_v29&utm_term=wordnet&spm=1018.2226.3001.4187
                all_english_words.append(yesisenglish)
    return all_english_words

seventh_tokens  = englishwords(seventh_tokens)
seventh_tokens
# Out:
# ['r',
#  'it',
#  'ENCYCLOPAEDIA',
#  'SEVENTH',
#  'EDITION',
#  'ENCYCLOPAEDIA',
#  'OR',
#  'DICTIONARY',
#  'ARTS',
#  'SCIENCES',
#  'GENERAL',
#  'LITERATURE',
#  'SEVENTH',
#  'EDITION',
#  'PRELIMINARY',
#  'DISSERTATIONS',
#  'ON',
#  'HISTORY',
#  'SCIENCES',
#  'OTHER',
#  'EXTENSIVE',
#  'IMPROVEMENTS',
#  'ADDITIONS',
#  'INCLUDING',
#  'LATE',
#  'SUPPLEMENT',
#  'A',
#  'GENERAL',
#  'INDEX',
#  'NUMEROUS',
#  'ENGRAVINGS',
#  'VOLUME',
#  'XII',
#  'ADAM',
#  'CHARLES',
#  'BLACK',
#  'EDINBURGH',
#  'M',
#  'XLII',
#  'ENCYCLOPEDIA',
#  'BRITANNIC',
#  'A',
#  'HYDRODYNAMICS',
#  'History',
#  'water',
#  'v',
#  'power',
#  'is',
#  'properly',
#  'science',
#  'Definition',
#  'treats',
#  'power',
#  'water',
#  'it',
#  'acts',
#  'by',
#  'pressure',
#  'or',
#  'by',
#  'impulse',
#  'In',
#  'its',
#  'more',
#  'enlarged',
#  'acceptation',
#  'ever',
#  'it',
#  'treats',
#  'pressure',
#  'equilibrium',
#  'cohesion',
#  'motion',
#  'fluids',
#  'machines',
#  'by',
#  'water',
#  'is',
#  'raised',
#  'or',
#  'in',
#  'fluid',
#  'is',
#  'employed',
#  'as',
#  'first',
#  'mover',
#  'Hydrodynamics',
#  'is',
#  'divided',
#  'two',
#  'Hydrostatics',
#  'Hydraulics',
#  'Hydrostatics',
#  'comprehends',
#  'pressure',
#  'equilibrium',
#  'cohesion',
#  'fluids',
#  'motion',
#  'together',
#  'machines',
#  'in',
#  'are',
#  'chiefly',
#  'concerned',
#  'HISTORY',
#  'science',
#  'hydrodynamics',
#  'was',
#  'cultivated',
#  'in',
#  'less',
#  'success',
#  'ancients',
#  'any',
#  'other',
#  'm',
#  'some',
#  're',
#  'mechanical',
#  'philosophy',
#  'human',
#  'mind',
#  'had',
#  'made',
#  'a',
#  'considerable',
#  'progress',
#  'in',
#  'other',
#  'departments',
#  'physical',
#  'science',
#  'doctrine',
#  'fluids',
#  'had',
#  'not',
#  'begun',
#  'occupy',
#  'attention',
#  'philosophers',
#  'except',
#  'a',
#  'few',
#  'on',
#  'pressure',
#  'equilibrium',
#  'water',
#  'must',
#  'be',
#  'regarded',
#  'as',
#  'a',
#  'modern',
#  'science',
#  'owes',
#  'its',
#  'existence',
#  'improvement',
#  'great',
#  'men',
#  'who',
#  'adorned',
#  'seventeenth',
#  'eighteenth',
#  'centuries',
#  'Discoveries',
#  'general',
#  'principles',
#  'hydrostatics',
#  'are',
#  'day',
#  'employed',
#  'as',
#  'foundation',
#  'part',
#  'science',
#  'were',
#  'first',
#  'given',
#  'by',
#  'Archimedes',
#  'in',
#  'work',
#  'A',
#  'C',
#  'h',
#  'or',
#  'De',
#  'about',
#  'years',
#  'be',
#  'fore',
#  'birth',
#  'Christ',
#  'were',
#  'afterwards',
#  'applied',
#  'ex',
#  'by',
#  'in',
#  'Archimedes',
#  'Hi',
#  'o',
#  'Archimedes',
#  'maintained',
#  'each',
#  'particle',
#  'a',
#  'fluid',
#  'mass',
#  'in',
#  'is',
#  'equally',
#  'pressed',
#  'in',
#  'every',
#  'direction',
#  'he',
#  'inquired',
#  'conditions',
#  'according',
#  'a',
#  'solid',
#  'body',
#  'floating',
#  'in',
#  'a',
#  'fluid',
#  'assume',
#  'preserve',
#  'a',
#  'position',
#  'equilibrium',
#  'are',
#  'also',
#  'in',
#  'philosopher',
#  'Syracuse',
#  'ingenious',
#  'XII',
#  'hydrostatic',
#  'process',
#  'by',
#  'purity',
#  'precious',
#  'History',
#  'metals',
#  'can',
#  'be',
#  'ascertained',
#  'screw',
#  'engine',
#  'v',
#  'goes',
#  'by',
#  'name',
#  'theory',
#  'has',
#  'lately',
#  'exer',
#  'ingenuity',
#  'some',
#  'greatest',
#  'In',
#  'Greek',
#  'school',
#  'at',
#  'Alexandria',
#  'flourished',
#  'under',
#  'auspices',
#  'Ptolemies',
#  'first',
#  'attempts',
#  'were',
#  'made',
#  'at',
#  'construction',
#  'hydraulic',
#  'machinery',
#  'About',
#  'years',
#  'after',
#  'birth',
#  'Christ',
#  'fountain',
#  'Inventions',
#  'compression',
#  'syphon',
#  'forcing',
#  'pump',
#  'were',
#  'in',
#  'vented',
#  'by',
#  'Hero',
#  'though',
#  'machines',
#  'operated',
#  'by',
#  'elasticity',
#  'weight',
#  'air',
#  'yet',
#  'inventors',
#  'had',
#  'no',
#  'distinct',
#  'notions',
#  'branches',
#  'science',
#  'he',
#  'syphon',
#  'is',
#  'a',
#  'simple',
#  'instrument',
#  'is',
#  'employed',
#  'empty',
#  'vessels',
#  'full',
#  'water',
#  'or',
#  'spirituous',
#  'liquors',
#  'is',
#  'great',
#  'utility',
#  'in',
#  'arts',
#  'forcing',
#  'pump',
#  'on',
#  'contrary',
#  'is',
#  'a',
#  'complicated',
#  'Forcing',
#  'abstruse',
#  'invention',
#  'scarcely',
#  'have',
#  'been',
#  'un',
#  'expected',
#  'in',
#  'infancy',
#  'hydraulics',
#  'It',
#  'was',
#  'probably',
#  'suggested',
#  'by',
#  'Egyptian',
#  'wheel',
#  'or',
#  'Noria',
#  'Egyptian',
#  'was',
#  'common',
#  'at',
#  'time',
#  'was',
#  'a',
#  'kind',
#  'wheel',
#  'chain',
#  'pump',
#  'consisting',
#  'a',
#  'number',
#  'pots',
#  'car',
#  'round',
#  'by',
#  'a',
#  'wheel',
#  'In',
#  'some',
#  'machine',
#  's',
#  'pots',
#  'have',
#  'a',
#  'valve',
#  'in',
#  'bottom',
#  'enables',
#  'descend',
#  'much',
#  'resistance',
#  'diminishes',
#  'greatly',
#  'load',
#  'wheel',
#  'suppose',
#  'valve',
#  'was',
#  'introduced',
#  'so',
#  'early',
#  'as',
#  'time',
#  'it',
#  'is',
#  'not',
#  'difficult',
#  'perceive',
#  'such',
#  'a',
#  'machine',
#  'might',
#  'have',
#  'led',
#  'philosopher',
#  'invention',
#  'forcing',
#  'Notwithstanding',
#  'inventions',
#  'Alexandrian',
#  'Labours',
#  'school',
#  'its',
#  'attention',
#  'does',
#  'not',
#  'seem',
#  'have',
#  'been',
#  'directed',
#  'u',
#  'motion',
#  'fluids',
#  'first',
#  'attempt',
#  'investigate',
#  'nus',
#  'in',
#  'subject',
#  'was',
#  'made',
#  'by',
#  'u',
#  'tor',
#  'public',
#  'fountains',
#  'at',
#  'Rome',
#  'in',
#  'reigns',
#  'Nerva',
#  'a',
#  'D',
#  'Trajan',
#  'may',
#  'justly',
#  'suppose',
#  'work',
#  'en',
#  'titled',
#  'De',
#  'con',
#  'all',
#  'hydraulic',
#  'knowledge',
#  'ancients',
#  'After',
#  'HYDRODYNAMICS',
#  'Ro',
#  'mans',
#  'ac',
#  'art',
#  'con',
#  'water',
#  'in',
#  'pipes',
#  'History',
#  'describing',
#  'nine',
#  'great',
#  'Roman',
#  'aqueducts',
#  'he',
#  'v',
#  'added',
#  'more',
#  'mentioning',
#  'dates',
#  'erection',
#  'he',
#  'considers',
#  'methods',
#  'were',
#  'at',
#  'time',
#  'employed',
#  'ascertaining',
#  'quantity',
#  'water',
#  'discharged',
#  'mode',
#  'distributing',
#  'waters',
#  'an',
#  'aqueduct',
#  'or',
#  'a',
#  'fountain',
#  'He',
#  'justly',
#  'remarks',
#  'expense',
#  'water',
#  'an',
#  'orifice',
#  'depended',
#  'not',
#  'only',
#  'on',
#  'magnitude',
#  'orifice',
#  'but',
#  'also',
#  'on',
#  'height',
#  'water',
#  'in',
#  'reservoir',
#  'a',
#  'pipe',
#  'employed',
#  'carry',
#  'off',
#  'a',
#  'portion',
#  'water',
#  'an',
#  'aqueduct',
#  'as',
#  'circumstances',
#  'required',
#  'have',
#  'a',
#  'position',
#  'more',
#  'or',
#  'less',
#  'in',
#  'original',
#  'direction',
#  'current',
#  'But',
#  'as',
#  'he',
#  'was',
#  'unacquainted',
#  'true',
#  'law',
#  'velocities',
#  'running',
#  'water',
#  'as',
#  'depending',
#  'depth',
#  'orifice',
#  'can',
#  'scarcely',
#  'be',
#  'surprised',
#  'at',
#  'want',
#  'precision',
#  'appears',
#  'in',
#  'results',
#  'It',
#  'has',
#  'generally',
#  'been',
#  'supposed',
#  'Romans',
#  'were',
#  'ignorant',
#  'art',
#  'conducting',
#  'raising',
#  'water',
#  'by',
#  'means',
#  'pipes',
#  'but',
#  'it',
#  'can',
#  'scarcely',
#  'be',
#  'doubted',
#  'statement',
#  'Pliny',
#  'other',
#  'authors',
#  'not',
#  'only',
#  'were',
#  'acquainted',
#  'principle',
#  'but',
#  'actually',
#  'used',
#  'leaden',
#  'pipes',
#  'purpose',
#  'Pliny',
#  'asserts',
#  'water',
#  'will',
#  'always',
#  'rise',
#  'height',
#  'its',
#  'source',
#  'he',
#  'also',
#  'adds',
#  'in',
#  'order',
#  'raise',
#  'water',
#  'up',
#  'an',
#  'leaden',
#  'pipes',
#  'must',
#  'be',
#  'employed',
#  'labours',
#  'ancients',
#  'in',
#  'science',
#  'dynamics',
#  'terminated',
#  'life',
#  'sciences',
#  'had',
#  'already',
#  'begun',
#  'decline',
#  'night',
#  'ignorance',
#  'barbarism',
#  'was',
#  'advancing',
#  'apace',
#  'more',
#  'a',
#  'thousand',
#  'years',
#  'brooded',
#  'over',
#  'nations',
#  'Europe',
#  'lengthened',
#  'period',
#  'mental',
#  'less',
#  'abstruse',
#  'studies',
#  'ceased',
#  'attract',
#  'no',
#  'rouse',
#  'energies',
#  'men',
#  'human',
#  'mind',
#  'not',
#  'be',
#  'supposed',
#  'capable',
#  'vigorous',
#  'exertion',
#  'patient',
#  'industry',
#  'are',
#  'so',
#  'indispensable',
#  'in',
#  'physical',
#  're',
#  'Labours',
#  'searches',
#  'Poetry',
#  'fine',
#  'arts',
#  'accordingly',
#  'had',
#  'made',
#  'Galileo',
#  'considerable',
#  'progress',
#  'under',
#  'patronage',
#  'family',
#  'Born',
#  'Medici',
#  'before',
#  'Galileo',
#  'began',
#  'extend',
#  'boundaries',
#  'died',
#  'great',
#  'man',
#  'who',
#  'deserves',
#  'be',
#  'called',
#  'father',
#  'restorer',
#  'physics',
#  'does',
#  'not',
#  'appear',
#  'have',
#  'attention',
#  'doctrine',
#  'fluids',
#  'but',
#  'dis',
#  'uniform',
#  'acceleration',
#  'gravity',
#  'laid',
#  'its',
#  'future',
#  'progress',
#  'contributed',
#  'in',
#  'no',
#  'small',
#  'degree',
#  'aid',
#  'exertions',
#  'genius',
#  'in',
#  'several',
#  'branches',
#  'science',
#  'Torricelli',
#  'two',
#  'disciples',
#  'Galileo',
#  'Born',
#  'applied',
#  'discoveries',
#  'master',
#  'science',
#  'died',
#  'hydrodynamics',
#  'In',
#  'published',
#  'a',
#  'small',
#  'work',
#  'dell',
#  'in',
#  'he',
#  'gave',
#  'a',
#  'very',
#  'satisfactory',
#  'explanation',
#  'several',
#  'phenomena',
#  'in',
#  'motion',
#  'fluids',
#  'in',
#  'rivers',
#  'canals',
#  'But',
#  'he',
#  'committed',
#  'a',
#  'great',
#  'paralogism',
#  'in',
#  'supposing',
#  'velocity',
#  'water',
#  'depth',
#  'orifice',
#  'below',
#  'surface',
#  'vessel',
#  'Torricelli',
#  'observing',
#  'in',
#  'a',
#  'jet',
#  'd',
#  'water',
#  'pushed',
#  'through',
#  'a',
#  'small',
#  'it',
#  'rose',
#  'nearly',
#  'Same',
#  'reservoir',
#  'it',
#  'was',
#  'sup',
#  'te',
#  'plied',
#  'imagined',
#  'it',
#  'move',
#  'same',
#  'city',
#  'as',
#  'it',
#  'had',
#  'fallen',
#  'through',
#  'height',
#  'by',
#  'force',
#  'gravity',
#  'hence',
#  'he',
#  'deduced',
#  'beautiful',
#  'proposition',
#  'velocities',
#  'fluids',
#  'are',
#  'as',
#  'square',
#  'roots',
#  'pressures',
#  'abstracting',
#  'resist',
#  'air',
#  'friction',
#  'orifice',
#  'rem',
#  'was',
#  'published',
#  'in',
#  'at',
#  'end',
#  'treatise',
#  'De',
#  'It',
#  'was',
#  'afterwards',
#  'confirmed',
#  'by',
#  'experiments',
#  'Raphael',
#  'on',
#  'quantities',
#  'water',
#  'discharged',
#  'different',
#  'History',
#  'under',
#  'different',
#  'pressures',
#  'though',
#  'it',
#  'is',
#  'true',
#  'only',
#  'in',
#  'small',
#  'orifices',
#  'it',
#  'gave',
#  'a',
#  'new',
#  'turn',
#  'science',
#  'hydraulics',
#  'After',
#  'death',
#  'celebrated',
#  'Pascal',
#  'who',
#  'dis',
#  'Pascal',
#  'covered',
#  'pressure',
#  'atmosphere',
#  'a',
#  'treatise',
#  'on',
#  'Born',
#  'equilibrium',
#  'fluids',
#  'Sur',
#  'des',
#  'Liqueurs',
#  'was',
#  'found',
#  'manuscripts',
#  'was',
#  'given',
#  'public',
#  'in',
#  'In',
#  'hands',
#  'Pascal',
#  'hydrostatics',
#  'assumed',
#  'dignity',
#  'a',
#  'science',
#  'laws',
#  'equilibrium',
#  'fluids',
#  'were',
#  'demonstrated',
#  'in',
#  'most',
#  'perspicuous',
#  'manner',
#  'amply',
#  'confirmed',
#  'by',
#  'experiments',
#  'discovery',
#  'Torricelli',
#  'it',
#  'may',
#  'be',
#  'supposed',
#  'have',
#  'incited',
#  'Pascal',
#  'study',
#  'hydraulics',
#  'But',
#  'as',
#  'he',
#  'has',
#  'not',
#  'treated',
#  'subject',
#  'in',
#  'work',
#  'has',
#  'been',
#  'men',
#  'it',
#  'was',
#  'probably',
#  'composed',
#  'before',
#  'discovery',
#  'had',
#  'been',
#  'made',
#  'public',
#  'theorem',
#  'Torricelli',
#  'was',
#  'employed',
#  'by',
#  'succeeding',
#  'writers',
#  'but',
#  'particularly',
#  'by',
#  'celebrated',
#  'Ma',
#  'labours',
#  'in',
#  'department',
#  'physics',
#  'deserve',
#  'Died',
#  'be',
#  'recorded',
#  'des',
#  'was',
#  'published',
#  'after',
#  'death',
#  'in',
#  'year',
#  'is',
#  'founded',
#  'on',
#  'a',
#  'great',
#  ...]

# %% [markdown]
# Delete all stopwords

# %%
#all the stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
#remove all the stopwords
en_stopwords = stopwords.words('english')

def remove_stopwords(text):
    result = []
    for token in text:
        if token not in en_stopwords:
            result.append(token)
    return result

seventh_tokens = remove_stopwords(seventh_tokens)
seventh_tokens
# Out:
# ['r',
#  'ENCYCLOPAEDIA',
#  'SEVENTH',
#  'EDITION',
#  'ENCYCLOPAEDIA',
#  'OR',
#  'DICTIONARY',
#  'ARTS',
#  'SCIENCES',
#  'GENERAL',
#  'LITERATURE',
#  'SEVENTH',
#  'EDITION',
#  'PRELIMINARY',
#  'DISSERTATIONS',
#  'ON',
#  'HISTORY',
#  'SCIENCES',
#  'OTHER',
#  'EXTENSIVE',
#  'IMPROVEMENTS',
#  'ADDITIONS',
#  'INCLUDING',
#  'LATE',
#  'SUPPLEMENT',
#  'A',
#  'GENERAL',
#  'INDEX',
#  'NUMEROUS',
#  'ENGRAVINGS',
#  'VOLUME',
#  'XII',
#  'ADAM',
#  'CHARLES',
#  'BLACK',
#  'EDINBURGH',
#  'M',
#  'XLII',
#  'ENCYCLOPEDIA',
#  'BRITANNIC',
#  'A',
#  'HYDRODYNAMICS',
#  'History',
#  'water',
#  'v',
#  'power',
#  'properly',
#  'science',
#  'Definition',
#  'treats',
#  'power',
#  'water',
#  'acts',
#  'pressure',
#  'impulse',
#  'In',
#  'enlarged',
#  'acceptation',
#  'ever',
#  'treats',
#  'pressure',
#  'equilibrium',
#  'cohesion',
#  'motion',
#  'fluids',
#  'machines',
#  'water',
#  'raised',
#  'fluid',
#  'employed',
#  'first',
#  'mover',
#  'Hydrodynamics',
#  'divided',
#  'two',
#  'Hydrostatics',
#  'Hydraulics',
#  'Hydrostatics',
#  'comprehends',
#  'pressure',
#  'equilibrium',
#  'cohesion',
#  'fluids',
#  'motion',
#  'together',
#  'machines',
#  'chiefly',
#  'concerned',
#  'HISTORY',
#  'science',
#  'hydrodynamics',
#  'cultivated',
#  'less',
#  'success',
#  'ancients',
#  'mechanical',
#  'philosophy',
#  'human',
#  'mind',
#  'made',
#  'considerable',
#  'progress',
#  'departments',
#  'physical',
#  'science',
#  'doctrine',
#  'fluids',
#  'begun',
#  'occupy',
#  'attention',
#  'philosophers',
#  'except',
#  'pressure',
#  'equilibrium',
#  'water',
#  'must',
#  'regarded',
#  'modern',
#  'science',
#  'owes',
#  'existence',
#  'improvement',
#  'great',
#  'men',
#  'adorned',
#  'seventeenth',
#  'eighteenth',
#  'centuries',
#  'Discoveries',
#  'general',
#  'principles',
#  'hydrostatics',
#  'day',
#  'employed',
#  'foundation',
#  'part',
#  'science',
#  'first',
#  'given',
#  'Archimedes',
#  'work',
#  'A',
#  'C',
#  'h',
#  'De',
#  'years',
#  'fore',
#  'birth',
#  'Christ',
#  'afterwards',
#  'applied',
#  'ex',
#  'Archimedes',
#  'Hi',
#  'Archimedes',
#  'maintained',
#  'particle',
#  'fluid',
#  'mass',
#  'equally',
#  'pressed',
#  'every',
#  'direction',
#  'inquired',
#  'conditions',
#  'according',
#  'solid',
#  'body',
#  'floating',
#  'fluid',
#  'assume',
#  'preserve',
#  'position',
#  'equilibrium',
#  'also',
#  'philosopher',
#  'Syracuse',
#  'ingenious',
#  'XII',
#  'hydrostatic',
#  'process',
#  'purity',
#  'precious',
#  'History',
#  'metals',
#  'ascertained',
#  'screw',
#  'engine',
#  'v',
#  'goes',
#  'name',
#  'theory',
#  'lately',
#  'exer',
#  'ingenuity',
#  'greatest',
#  'In',
#  'Greek',
#  'school',
#  'Alexandria',
#  'flourished',
#  'auspices',
#  'Ptolemies',
#  'first',
#  'attempts',
#  'made',
#  'construction',
#  'hydraulic',
#  'machinery',
#  'About',
#  'years',
#  'birth',
#  'Christ',
#  'fountain',
#  'Inventions',
#  'compression',
#  'syphon',
#  'forcing',
#  'pump',
#  'vented',
#  'Hero',
#  'though',
#  'machines',
#  'operated',
#  'elasticity',
#  'weight',
#  'air',
#  'yet',
#  'inventors',
#  'distinct',
#  'notions',
#  'branches',
#  'science',
#  'syphon',
#  'simple',
#  'instrument',
#  'employed',
#  'empty',
#  'vessels',
#  'full',
#  'water',
#  'spirituous',
#  'liquors',
#  'great',
#  'utility',
#  'arts',
#  'forcing',
#  'pump',
#  'contrary',
#  'complicated',
#  'Forcing',
#  'abstruse',
#  'invention',
#  'scarcely',
#  'un',
#  'expected',
#  'infancy',
#  'hydraulics',
#  'It',
#  'probably',
#  'suggested',
#  'Egyptian',
#  'wheel',
#  'Noria',
#  'Egyptian',
#  'common',
#  'time',
#  'kind',
#  'wheel',
#  'chain',
#  'pump',
#  'consisting',
#  'number',
#  'pots',
#  'car',
#  'round',
#  'wheel',
#  'In',
#  'machine',
#  'pots',
#  'valve',
#  'bottom',
#  'enables',
#  'descend',
#  'much',
#  'resistance',
#  'diminishes',
#  'greatly',
#  'load',
#  'wheel',
#  'suppose',
#  'valve',
#  'introduced',
#  'early',
#  'time',
#  'difficult',
#  'perceive',
#  'machine',
#  'might',
#  'led',
#  'philosopher',
#  'invention',
#  'forcing',
#  'Notwithstanding',
#  'inventions',
#  'Alexandrian',
#  'Labours',
#  'school',
#  'attention',
#  'seem',
#  'directed',
#  'u',
#  'motion',
#  'fluids',
#  'first',
#  'attempt',
#  'investigate',
#  'nus',
#  'subject',
#  'made',
#  'u',
#  'tor',
#  'public',
#  'fountains',
#  'Rome',
#  'reigns',
#  'Nerva',
#  'D',
#  'Trajan',
#  'may',
#  'justly',
#  'suppose',
#  'work',
#  'en',
#  'titled',
#  'De',
#  'con',
#  'hydraulic',
#  'knowledge',
#  'ancients',
#  'After',
#  'HYDRODYNAMICS',
#  'Ro',
#  'mans',
#  'ac',
#  'art',
#  'con',
#  'water',
#  'pipes',
#  'History',
#  'describing',
#  'nine',
#  'great',
#  'Roman',
#  'aqueducts',
#  'v',
#  'added',
#  'mentioning',
#  'dates',
#  'erection',
#  'considers',
#  'methods',
#  'time',
#  'employed',
#  'ascertaining',
#  'quantity',
#  'water',
#  'discharged',
#  'mode',
#  'distributing',
#  'waters',
#  'aqueduct',
#  'fountain',
#  'He',
#  'justly',
#  'remarks',
#  'expense',
#  'water',
#  'orifice',
#  'depended',
#  'magnitude',
#  'orifice',
#  'also',
#  'height',
#  'water',
#  'reservoir',
#  'pipe',
#  'employed',
#  'carry',
#  'portion',
#  'water',
#  'aqueduct',
#  'circumstances',
#  'required',
#  'position',
#  'less',
#  'original',
#  'direction',
#  'current',
#  'But',
#  'unacquainted',
#  'true',
#  'law',
#  'velocities',
#  'running',
#  'water',
#  'depending',
#  'depth',
#  'orifice',
#  'scarcely',
#  'surprised',
#  'want',
#  'precision',
#  'appears',
#  'results',
#  'It',
#  'generally',
#  'supposed',
#  'Romans',
#  'ignorant',
#  'art',
#  'conducting',
#  'raising',
#  'water',
#  'means',
#  'pipes',
#  'scarcely',
#  'doubted',
#  'statement',
#  'Pliny',
#  'authors',
#  'acquainted',
#  'principle',
#  'actually',
#  'used',
#  'leaden',
#  'pipes',
#  'purpose',
#  'Pliny',
#  'asserts',
#  'water',
#  'always',
#  'rise',
#  'height',
#  'source',
#  'also',
#  'adds',
#  'order',
#  'raise',
#  'water',
#  'leaden',
#  'pipes',
#  'must',
#  'employed',
#  'labours',
#  'ancients',
#  'science',
#  'dynamics',
#  'terminated',
#  'life',
#  'sciences',
#  'already',
#  'begun',
#  'decline',
#  'night',
#  'ignorance',
#  'barbarism',
#  'advancing',
#  'apace',
#  'thousand',
#  'years',
#  'brooded',
#  'nations',
#  'Europe',
#  'lengthened',
#  'period',
#  'mental',
#  'less',
#  'abstruse',
#  'studies',
#  'ceased',
#  'attract',
#  'rouse',
#  'energies',
#  'men',
#  'human',
#  'mind',
#  'supposed',
#  'capable',
#  'vigorous',
#  'exertion',
#  'patient',
#  'industry',
#  'indispensable',
#  'physical',
#  'Labours',
#  'searches',
#  'Poetry',
#  'fine',
#  'arts',
#  'accordingly',
#  'made',
#  'Galileo',
#  'considerable',
#  'progress',
#  'patronage',
#  'family',
#  'Born',
#  'Medici',
#  'Galileo',
#  'began',
#  'extend',
#  'boundaries',
#  'died',
#  'great',
#  'man',
#  'deserves',
#  'called',
#  'father',
#  'restorer',
#  'physics',
#  'appear',
#  'attention',
#  'doctrine',
#  'fluids',
#  'dis',
#  'uniform',
#  'acceleration',
#  'gravity',
#  'laid',
#  'future',
#  'progress',
#  'contributed',
#  'small',
#  'degree',
#  'aid',
#  'exertions',
#  'genius',
#  'several',
#  'branches',
#  'science',
#  'Torricelli',
#  'two',
#  'disciples',
#  'Galileo',
#  'Born',
#  'applied',
#  'discoveries',
#  'master',
#  'science',
#  'died',
#  'hydrodynamics',
#  'In',
#  'published',
#  'small',
#  'work',
#  'dell',
#  'gave',
#  'satisfactory',
#  'explanation',
#  'several',
#  'phenomena',
#  'motion',
#  'fluids',
#  'rivers',
#  'canals',
#  'But',
#  'committed',
#  'great',
#  'paralogism',
#  'supposing',
#  'velocity',
#  'water',
#  'depth',
#  'orifice',
#  'surface',
#  'vessel',
#  'Torricelli',
#  'observing',
#  'jet',
#  'water',
#  'pushed',
#  'small',
#  'rose',
#  'nearly',
#  'Same',
#  'reservoir',
#  'sup',
#  'te',
#  'plied',
#  'imagined',
#  'move',
#  'city',
#  'fallen',
#  'height',
#  'force',
#  'gravity',
#  'hence',
#  'deduced',
#  'beautiful',
#  'proposition',
#  'velocities',
#  'fluids',
#  'square',
#  'roots',
#  'pressures',
#  'abstracting',
#  'resist',
#  'air',
#  'friction',
#  'orifice',
#  'rem',
#  'published',
#  'end',
#  'treatise',
#  'De',
#  'It',
#  'afterwards',
#  'confirmed',
#  'experiments',
#  'Raphael',
#  'quantities',
#  'water',
#  'discharged',
#  'different',
#  'History',
#  'different',
#  'pressures',
#  'though',
#  'true',
#  'small',
#  'orifices',
#  'gave',
#  'new',
#  'turn',
#  'science',
#  'hydraulics',
#  'After',
#  'death',
#  'celebrated',
#  'Pascal',
#  'dis',
#  'Pascal',
#  'covered',
#  'pressure',
#  'atmosphere',
#  'treatise',
#  'Born',
#  'equilibrium',
#  'fluids',
#  'Sur',
#  'des',
#  'Liqueurs',
#  'found',
#  'manuscripts',
#  'given',
#  'public',
#  'In',
#  'hands',
#  'Pascal',
#  'hydrostatics',
#  'assumed',
#  'dignity',
#  'science',
#  'laws',
#  'equilibrium',
#  'fluids',
#  'demonstrated',
#  'perspicuous',
#  'manner',
#  'amply',
#  'confirmed',
#  'experiments',
#  'discovery',
#  'Torricelli',
#  'may',
#  'supposed',
#  'incited',
#  'Pascal',
#  'study',
#  'hydraulics',
#  'But',
#  'treated',
#  'subject',
#  'work',
#  'men',
#  'probably',
#  'composed',
#  'discovery',
#  'made',
#  'public',
#  'theorem',
#  'Torricelli',
#  'employed',
#  'succeeding',
#  'writers',
#  'particularly',
#  'celebrated',
#  'Ma',
#  'labours',
#  'department',
#  'physics',
#  'deserve',
#  'Died',
#  'recorded',
#  'des',
#  'published',
#  'death',
#  'year',
#  'founded',
#  'great',
#  'variety',
#  'well',
#  'conducted',
#  'experiments',
#  'motion',
#  'fluids',
#  'performed',
#  'Versailles',
#  'In',
#  'discussion',
#  'points',
#  'committed',
#  'considerable',
#  'mistakes',
#  'treated',
#  'superficially',
#  'none',
#  'experiments',
#  'seem',
#  'attended',
#  'diminution',
#  'efflux',
#  'arising',
#  'contraction',
#  'fluid',
#  'vein',
#  'orifice',
#  'merely',
#  'perforation',
#  'thin',
#  'plate',
#  'appears',
#  'first',
#  'attempted',
#  'ascribe',
#  'discrepancy',
#  'theory',
#  'experiment',
#  'retardation',
#  'water',
#  'velocity',
#  'arising',
#  'inspector',
#  'rivers',
#  'canals',
#  'Milanese',
#  'ascribed',
#  'velocity',
#  'rivers',
#  'transverse',
#  'motions',
#  'arising',
#  'inequalities',
#  'bottom',
#  'But',
#  'ob',
#  'served',
#  'similar',
#  'obstructions',
#  'even',
#  'glass',
#  'pipes',
#  'transverse',
#  'currents',
#  'exist',
#  'cause',
#  'assigned',
#  'seemed',
#  'destitute',
#  'foundation',
#  'French',
#  'philosopher',
#  'therefore',
#  'regarded',
#  'obstructions',
#  'effects',
#  'friction',
#  'He',
#  'supposes',
#  'filaments',
#  'water',
#  'graze',
#  'along',
#  'sides',
#  'pipe',
#  'lose',
#  'portion',
#  'velocity',
#  'contiguous',
#  'filaments',
#  'account',
#  'greater',
#  'velocity',
#  'rub',
#  'former',
#  'suffer',
#  'diminution',
#  'celerity',
#  'filaments',
#  'affected',
#  'similar',
#  'retardations',
#  'proportional',
#  'distance',
#  'axis',
#  'pipe',
#  'In',
#  'way',
#  'medium',
#  'velocity',
#  'current',
#  'may',
#  'diminished',
#  'consequent',
#  'quantity',
#  'water',
#  'discharged',
#  'given',
#  'time',
#  'must',
#  'effects',
#  'friction',
#  'considerably',
#  'less',
#  'computed',
#  'theory',
#  'part',
#  'science',
#  'hydrodynamics',
#  'mo',
#  'relates',
#  'motion',
#  'rivers',
#  'seems',
#  'originated',
#  'Italy',
#  'fertile',
#  'country',
#  'receives',
#  'Apennines',
#  'first',
#  'great',
#  'number',
#  'torrents',
#  'traverse',
#  'several',
#  'tended',
#  'mingle',
#  'waters',
#  'Po',
#  'greater',
#  'part',
#  'fall',
#  'defend',
#  'inundations',
#  'threatened',
#  'became',
#  'necessary',
#  'inhabitants',
#  'change',
#  'course',
#  'rivers',
#  'thus',
#  'drove',
#  'territories',
#  'let',
#  'loose',
#  'neighbours',
#  'Hence',
#  'arose',
#  'continual',
#  'quarrels',
#  'raged',
#  'inhabitants',
#  'Ferrara',
#  'attention',
#  'Italian',
#  'engineers',
#  'necessarily',
#  'directed',
#  'branch',
#  'science',
#  'cause',
#  'greater',
#  'number',
#  'works',
#  'nine',
#  'aqueducts',
#  'delivered',
#  'every',
#  'day',
#  'cubic',
#  'feet',
#  'water',
#  'cubic',
#  'feet',
#  'consumption',
#  'inhabitant',
#  'supposing',
#  'population',
#  'Rome',
#  'million',
#  'According',
#  'Professor',
#  'supply',
#  'modern',
#  'Rome',
#  'forty',
#  'cubic',
#  'feet',
#  'person',
#  'London',
#  'three',
#  'cubic',
#  'feet',
#  'Paris',
#  'one',
#  'half',
#  'cubic',
#  'foot',
#  'See',
#  'Elements',
#  'p',
#  'xxxvi',
#  'See',
#  'also',
#  'De',
#  'Be',
#  'ix',
#  'c',
#  'Horace',
#  'I',
#  'x',
#  'Ovid',
#  'Met',
#  'iv',
#  'HYDRODYNAMICS',
#  'History',
#  'Theory',
#  'mini',
#  'written',
#  'subject',
#  'Italy',
#  'rest',
#  'Europe',
#  'first',
#  'attended',
#  'mo',
#  'water',
#  'rivers',
#  'open',
#  'canals',
#  'Embracing',
#  'theorem',
#  'Torricelli',
#  'confirmed',
#  'repeated',
#  'experiments',
#  'concluded',
#  'particle',
#  'perpendicular',
#  'section',
#  'current',
#  'tendency',
#  'move',
#  'velocity',
#  'issued',
#  'orifice',
#  'depth',
#  'surface',
#  'consequences',
#  'deducible',
#  'theory',
#  'running',
#  'waters',
#  'every',
#  'respect',
#  'repugnant',
#  'experience',
#  'really',
#  'surprising',
#  'hastily',
#  'adopted',
#  'succeed',
#  'writers',
#  'sufficiently',
#  'sensible',
#  'parabolic',
#  'theory',
#  ...]

# %% [markdown]
# Change all upper case letters to lower case to facilitate subsequent statistics

# %%
#lowercase
seventh_tokens_low = [t.lower() for t in seventh_tokens]
seventh_tokens_low
# Out:
# ['r',
#  'encyclopaedia',
#  'seventh',
#  'edition',
#  'encyclopaedia',
#  'or',
#  'dictionary',
#  'arts',
#  'sciences',
#  'general',
#  'literature',
#  'seventh',
#  'edition',
#  'preliminary',
#  'dissertations',
#  'on',
#  'history',
#  'sciences',
#  'other',
#  'extensive',
#  'improvements',
#  'additions',
#  'including',
#  'late',
#  'supplement',
#  'a',
#  'general',
#  'index',
#  'numerous',
#  'engravings',
#  'volume',
#  'xii',
#  'adam',
#  'charles',
#  'black',
#  'edinburgh',
#  'm',
#  'xlii',
#  'encyclopedia',
#  'britannic',
#  'a',
#  'hydrodynamics',
#  'history',
#  'water',
#  'v',
#  'power',
#  'properly',
#  'science',
#  'definition',
#  'treats',
#  'power',
#  'water',
#  'acts',
#  'pressure',
#  'impulse',
#  'in',
#  'enlarged',
#  'acceptation',
#  'ever',
#  'treats',
#  'pressure',
#  'equilibrium',
#  'cohesion',
#  'motion',
#  'fluids',
#  'machines',
#  'water',
#  'raised',
#  'fluid',
#  'employed',
#  'first',
#  'mover',
#  'hydrodynamics',
#  'divided',
#  'two',
#  'hydrostatics',
#  'hydraulics',
#  'hydrostatics',
#  'comprehends',
#  'pressure',
#  'equilibrium',
#  'cohesion',
#  'fluids',
#  'motion',
#  'together',
#  'machines',
#  'chiefly',
#  'concerned',
#  'history',
#  'science',
#  'hydrodynamics',
#  'cultivated',
#  'less',
#  'success',
#  'ancients',
#  'mechanical',
#  'philosophy',
#  'human',
#  'mind',
#  'made',
#  'considerable',
#  'progress',
#  'departments',
#  'physical',
#  'science',
#  'doctrine',
#  'fluids',
#  'begun',
#  'occupy',
#  'attention',
#  'philosophers',
#  'except',
#  'pressure',
#  'equilibrium',
#  'water',
#  'must',
#  'regarded',
#  'modern',
#  'science',
#  'owes',
#  'existence',
#  'improvement',
#  'great',
#  'men',
#  'adorned',
#  'seventeenth',
#  'eighteenth',
#  'centuries',
#  'discoveries',
#  'general',
#  'principles',
#  'hydrostatics',
#  'day',
#  'employed',
#  'foundation',
#  'part',
#  'science',
#  'first',
#  'given',
#  'archimedes',
#  'work',
#  'a',
#  'c',
#  'h',
#  'de',
#  'years',
#  'fore',
#  'birth',
#  'christ',
#  'afterwards',
#  'applied',
#  'ex',
#  'archimedes',
#  'hi',
#  'archimedes',
#  'maintained',
#  'particle',
#  'fluid',
#  'mass',
#  'equally',
#  'pressed',
#  'every',
#  'direction',
#  'inquired',
#  'conditions',
#  'according',
#  'solid',
#  'body',
#  'floating',
#  'fluid',
#  'assume',
#  'preserve',
#  'position',
#  'equilibrium',
#  'also',
#  'philosopher',
#  'syracuse',
#  'ingenious',
#  'xii',
#  'hydrostatic',
#  'process',
#  'purity',
#  'precious',
#  'history',
#  'metals',
#  'ascertained',
#  'screw',
#  'engine',
#  'v',
#  'goes',
#  'name',
#  'theory',
#  'lately',
#  'exer',
#  'ingenuity',
#  'greatest',
#  'in',
#  'greek',
#  'school',
#  'alexandria',
#  'flourished',
#  'auspices',
#  'ptolemies',
#  'first',
#  'attempts',
#  'made',
#  'construction',
#  'hydraulic',
#  'machinery',
#  'about',
#  'years',
#  'birth',
#  'christ',
#  'fountain',
#  'inventions',
#  'compression',
#  'syphon',
#  'forcing',
#  'pump',
#  'vented',
#  'hero',
#  'though',
#  'machines',
#  'operated',
#  'elasticity',
#  'weight',
#  'air',
#  'yet',
#  'inventors',
#  'distinct',
#  'notions',
#  'branches',
#  'science',
#  'syphon',
#  'simple',
#  'instrument',
#  'employed',
#  'empty',
#  'vessels',
#  'full',
#  'water',
#  'spirituous',
#  'liquors',
#  'great',
#  'utility',
#  'arts',
#  'forcing',
#  'pump',
#  'contrary',
#  'complicated',
#  'forcing',
#  'abstruse',
#  'invention',
#  'scarcely',
#  'un',
#  'expected',
#  'infancy',
#  'hydraulics',
#  'it',
#  'probably',
#  'suggested',
#  'egyptian',
#  'wheel',
#  'noria',
#  'egyptian',
#  'common',
#  'time',
#  'kind',
#  'wheel',
#  'chain',
#  'pump',
#  'consisting',
#  'number',
#  'pots',
#  'car',
#  'round',
#  'wheel',
#  'in',
#  'machine',
#  'pots',
#  'valve',
#  'bottom',
#  'enables',
#  'descend',
#  'much',
#  'resistance',
#  'diminishes',
#  'greatly',
#  'load',
#  'wheel',
#  'suppose',
#  'valve',
#  'introduced',
#  'early',
#  'time',
#  'difficult',
#  'perceive',
#  'machine',
#  'might',
#  'led',
#  'philosopher',
#  'invention',
#  'forcing',
#  'notwithstanding',
#  'inventions',
#  'alexandrian',
#  'labours',
#  'school',
#  'attention',
#  'seem',
#  'directed',
#  'u',
#  'motion',
#  'fluids',
#  'first',
#  'attempt',
#  'investigate',
#  'nus',
#  'subject',
#  'made',
#  'u',
#  'tor',
#  'public',
#  'fountains',
#  'rome',
#  'reigns',
#  'nerva',
#  'd',
#  'trajan',
#  'may',
#  'justly',
#  'suppose',
#  'work',
#  'en',
#  'titled',
#  'de',
#  'con',
#  'hydraulic',
#  'knowledge',
#  'ancients',
#  'after',
#  'hydrodynamics',
#  'ro',
#  'mans',
#  'ac',
#  'art',
#  'con',
#  'water',
#  'pipes',
#  'history',
#  'describing',
#  'nine',
#  'great',
#  'roman',
#  'aqueducts',
#  'v',
#  'added',
#  'mentioning',
#  'dates',
#  'erection',
#  'considers',
#  'methods',
#  'time',
#  'employed',
#  'ascertaining',
#  'quantity',
#  'water',
#  'discharged',
#  'mode',
#  'distributing',
#  'waters',
#  'aqueduct',
#  'fountain',
#  'he',
#  'justly',
#  'remarks',
#  'expense',
#  'water',
#  'orifice',
#  'depended',
#  'magnitude',
#  'orifice',
#  'also',
#  'height',
#  'water',
#  'reservoir',
#  'pipe',
#  'employed',
#  'carry',
#  'portion',
#  'water',
#  'aqueduct',
#  'circumstances',
#  'required',
#  'position',
#  'less',
#  'original',
#  'direction',
#  'current',
#  'but',
#  'unacquainted',
#  'true',
#  'law',
#  'velocities',
#  'running',
#  'water',
#  'depending',
#  'depth',
#  'orifice',
#  'scarcely',
#  'surprised',
#  'want',
#  'precision',
#  'appears',
#  'results',
#  'it',
#  'generally',
#  'supposed',
#  'romans',
#  'ignorant',
#  'art',
#  'conducting',
#  'raising',
#  'water',
#  'means',
#  'pipes',
#  'scarcely',
#  'doubted',
#  'statement',
#  'pliny',
#  'authors',
#  'acquainted',
#  'principle',
#  'actually',
#  'used',
#  'leaden',
#  'pipes',
#  'purpose',
#  'pliny',
#  'asserts',
#  'water',
#  'always',
#  'rise',
#  'height',
#  'source',
#  'also',
#  'adds',
#  'order',
#  'raise',
#  'water',
#  'leaden',
#  'pipes',
#  'must',
#  'employed',
#  'labours',
#  'ancients',
#  'science',
#  'dynamics',
#  'terminated',
#  'life',
#  'sciences',
#  'already',
#  'begun',
#  'decline',
#  'night',
#  'ignorance',
#  'barbarism',
#  'advancing',
#  'apace',
#  'thousand',
#  'years',
#  'brooded',
#  'nations',
#  'europe',
#  'lengthened',
#  'period',
#  'mental',
#  'less',
#  'abstruse',
#  'studies',
#  'ceased',
#  'attract',
#  'rouse',
#  'energies',
#  'men',
#  'human',
#  'mind',
#  'supposed',
#  'capable',
#  'vigorous',
#  'exertion',
#  'patient',
#  'industry',
#  'indispensable',
#  'physical',
#  'labours',
#  'searches',
#  'poetry',
#  'fine',
#  'arts',
#  'accordingly',
#  'made',
#  'galileo',
#  'considerable',
#  'progress',
#  'patronage',
#  'family',
#  'born',
#  'medici',
#  'galileo',
#  'began',
#  'extend',
#  'boundaries',
#  'died',
#  'great',
#  'man',
#  'deserves',
#  'called',
#  'father',
#  'restorer',
#  'physics',
#  'appear',
#  'attention',
#  'doctrine',
#  'fluids',
#  'dis',
#  'uniform',
#  'acceleration',
#  'gravity',
#  'laid',
#  'future',
#  'progress',
#  'contributed',
#  'small',
#  'degree',
#  'aid',
#  'exertions',
#  'genius',
#  'several',
#  'branches',
#  'science',
#  'torricelli',
#  'two',
#  'disciples',
#  'galileo',
#  'born',
#  'applied',
#  'discoveries',
#  'master',
#  'science',
#  'died',
#  'hydrodynamics',
#  'in',
#  'published',
#  'small',
#  'work',
#  'dell',
#  'gave',
#  'satisfactory',
#  'explanation',
#  'several',
#  'phenomena',
#  'motion',
#  'fluids',
#  'rivers',
#  'canals',
#  'but',
#  'committed',
#  'great',
#  'paralogism',
#  'supposing',
#  'velocity',
#  'water',
#  'depth',
#  'orifice',
#  'surface',
#  'vessel',
#  'torricelli',
#  'observing',
#  'jet',
#  'water',
#  'pushed',
#  'small',
#  'rose',
#  'nearly',
#  'same',
#  'reservoir',
#  'sup',
#  'te',
#  'plied',
#  'imagined',
#  'move',
#  'city',
#  'fallen',
#  'height',
#  'force',
#  'gravity',
#  'hence',
#  'deduced',
#  'beautiful',
#  'proposition',
#  'velocities',
#  'fluids',
#  'square',
#  'roots',
#  'pressures',
#  'abstracting',
#  'resist',
#  'air',
#  'friction',
#  'orifice',
#  'rem',
#  'published',
#  'end',
#  'treatise',
#  'de',
#  'it',
#  'afterwards',
#  'confirmed',
#  'experiments',
#  'raphael',
#  'quantities',
#  'water',
#  'discharged',
#  'different',
#  'history',
#  'different',
#  'pressures',
#  'though',
#  'true',
#  'small',
#  'orifices',
#  'gave',
#  'new',
#  'turn',
#  'science',
#  'hydraulics',
#  'after',
#  'death',
#  'celebrated',
#  'pascal',
#  'dis',
#  'pascal',
#  'covered',
#  'pressure',
#  'atmosphere',
#  'treatise',
#  'born',
#  'equilibrium',
#  'fluids',
#  'sur',
#  'des',
#  'liqueurs',
#  'found',
#  'manuscripts',
#  'given',
#  'public',
#  'in',
#  'hands',
#  'pascal',
#  'hydrostatics',
#  'assumed',
#  'dignity',
#  'science',
#  'laws',
#  'equilibrium',
#  'fluids',
#  'demonstrated',
#  'perspicuous',
#  'manner',
#  'amply',
#  'confirmed',
#  'experiments',
#  'discovery',
#  'torricelli',
#  'may',
#  'supposed',
#  'incited',
#  'pascal',
#  'study',
#  'hydraulics',
#  'but',
#  'treated',
#  'subject',
#  'work',
#  'men',
#  'probably',
#  'composed',
#  'discovery',
#  'made',
#  'public',
#  'theorem',
#  'torricelli',
#  'employed',
#  'succeeding',
#  'writers',
#  'particularly',
#  'celebrated',
#  'ma',
#  'labours',
#  'department',
#  'physics',
#  'deserve',
#  'died',
#  'recorded',
#  'des',
#  'published',
#  'death',
#  'year',
#  'founded',
#  'great',
#  'variety',
#  'well',
#  'conducted',
#  'experiments',
#  'motion',
#  'fluids',
#  'performed',
#  'versailles',
#  'in',
#  'discussion',
#  'points',
#  'committed',
#  'considerable',
#  'mistakes',
#  'treated',
#  'superficially',
#  'none',
#  'experiments',
#  'seem',
#  'attended',
#  'diminution',
#  'efflux',
#  'arising',
#  'contraction',
#  'fluid',
#  'vein',
#  'orifice',
#  'merely',
#  'perforation',
#  'thin',
#  'plate',
#  'appears',
#  'first',
#  'attempted',
#  'ascribe',
#  'discrepancy',
#  'theory',
#  'experiment',
#  'retardation',
#  'water',
#  'velocity',
#  'arising',
#  'inspector',
#  'rivers',
#  'canals',
#  'milanese',
#  'ascribed',
#  'velocity',
#  'rivers',
#  'transverse',
#  'motions',
#  'arising',
#  'inequalities',
#  'bottom',
#  'but',
#  'ob',
#  'served',
#  'similar',
#  'obstructions',
#  'even',
#  'glass',
#  'pipes',
#  'transverse',
#  'currents',
#  'exist',
#  'cause',
#  'assigned',
#  'seemed',
#  'destitute',
#  'foundation',
#  'french',
#  'philosopher',
#  'therefore',
#  'regarded',
#  'obstructions',
#  'effects',
#  'friction',
#  'he',
#  'supposes',
#  'filaments',
#  'water',
#  'graze',
#  'along',
#  'sides',
#  'pipe',
#  'lose',
#  'portion',
#  'velocity',
#  'contiguous',
#  'filaments',
#  'account',
#  'greater',
#  'velocity',
#  'rub',
#  'former',
#  'suffer',
#  'diminution',
#  'celerity',
#  'filaments',
#  'affected',
#  'similar',
#  'retardations',
#  'proportional',
#  'distance',
#  'axis',
#  'pipe',
#  'in',
#  'way',
#  'medium',
#  'velocity',
#  'current',
#  'may',
#  'diminished',
#  'consequent',
#  'quantity',
#  'water',
#  'discharged',
#  'given',
#  'time',
#  'must',
#  'effects',
#  'friction',
#  'considerably',
#  'less',
#  'computed',
#  'theory',
#  'part',
#  'science',
#  'hydrodynamics',
#  'mo',
#  'relates',
#  'motion',
#  'rivers',
#  'seems',
#  'originated',
#  'italy',
#  'fertile',
#  'country',
#  'receives',
#  'apennines',
#  'first',
#  'great',
#  'number',
#  'torrents',
#  'traverse',
#  'several',
#  'tended',
#  'mingle',
#  'waters',
#  'po',
#  'greater',
#  'part',
#  'fall',
#  'defend',
#  'inundations',
#  'threatened',
#  'became',
#  'necessary',
#  'inhabitants',
#  'change',
#  'course',
#  'rivers',
#  'thus',
#  'drove',
#  'territories',
#  'let',
#  'loose',
#  'neighbours',
#  'hence',
#  'arose',
#  'continual',
#  'quarrels',
#  'raged',
#  'inhabitants',
#  'ferrara',
#  'attention',
#  'italian',
#  'engineers',
#  'necessarily',
#  'directed',
#  'branch',
#  'science',
#  'cause',
#  'greater',
#  'number',
#  'works',
#  'nine',
#  'aqueducts',
#  'delivered',
#  'every',
#  'day',
#  'cubic',
#  'feet',
#  'water',
#  'cubic',
#  'feet',
#  'consumption',
#  'inhabitant',
#  'supposing',
#  'population',
#  'rome',
#  'million',
#  'according',
#  'professor',
#  'supply',
#  'modern',
#  'rome',
#  'forty',
#  'cubic',
#  'feet',
#  'person',
#  'london',
#  'three',
#  'cubic',
#  'feet',
#  'paris',
#  'one',
#  'half',
#  'cubic',
#  'foot',
#  'see',
#  'elements',
#  'p',
#  'xxxvi',
#  'see',
#  'also',
#  'de',
#  'be',
#  'ix',
#  'c',
#  'horace',
#  'i',
#  'x',
#  'ovid',
#  'met',
#  'iv',
#  'hydrodynamics',
#  'history',
#  'theory',
#  'mini',
#  'written',
#  'subject',
#  'italy',
#  'rest',
#  'europe',
#  'first',
#  'attended',
#  'mo',
#  'water',
#  'rivers',
#  'open',
#  'canals',
#  'embracing',
#  'theorem',
#  'torricelli',
#  'confirmed',
#  'repeated',
#  'experiments',
#  'concluded',
#  'particle',
#  'perpendicular',
#  'section',
#  'current',
#  'tendency',
#  'move',
#  'velocity',
#  'issued',
#  'orifice',
#  'depth',
#  'surface',
#  'consequences',
#  'deducible',
#  'theory',
#  'running',
#  'waters',
#  'every',
#  'respect',
#  'repugnant',
#  'experience',
#  'really',
#  'surprising',
#  'hastily',
#  'adopted',
#  'succeed',
#  'writers',
#  'sufficiently',
#  'sensible',
#  'parabolic',
#  'theory',
#  ...]

# %% [markdown]
# Lemmatization is converting the word to its base form or lemma by removing affixes from the inflected words.

# %%
#https://machinelearningknowledge.ai/11-techniques-of-text-preprocessing-using-nltk-in-python/
#lemmatization
def lemmatization(text):
    result = []
    wnl = WordNetLemmatizer()
    for token, tag in pos_tag(text):
        pos = tag[0].lower()
        if pos not in ['a','n','v','r']:
            pos = 'n'
        result.append(wnl.lemmatize(token,pos))
    return result

seventh_tokens_le = lemmatization(seventh_tokens_low)
seventh_tokens_le
# Out:
# ['r',
#  'encyclopaedia',
#  'seventh',
#  'edition',
#  'encyclopaedia',
#  'or',
#  'dictionary',
#  'art',
#  'science',
#  'general',
#  'literature',
#  'seventh',
#  'edition',
#  'preliminary',
#  'dissertation',
#  'on',
#  'history',
#  'science',
#  'other',
#  'extensive',
#  'improvement',
#  'addition',
#  'include',
#  'late',
#  'supplement',
#  'a',
#  'general',
#  'index',
#  'numerous',
#  'engraving',
#  'volume',
#  'xii',
#  'adam',
#  'charles',
#  'black',
#  'edinburgh',
#  'm',
#  'xlii',
#  'encyclopedia',
#  'britannic',
#  'a',
#  'hydrodynamics',
#  'history',
#  'water',
#  'v',
#  'power',
#  'properly',
#  'science',
#  'definition',
#  'treat',
#  'power',
#  'water',
#  'act',
#  'pressure',
#  'impulse',
#  'in',
#  'enlarged',
#  'acceptation',
#  'ever',
#  'treat',
#  'pressure',
#  'equilibrium',
#  'cohesion',
#  'motion',
#  'fluid',
#  'machine',
#  'water',
#  'raise',
#  'fluid',
#  'employ',
#  'first',
#  'mover',
#  'hydrodynamics',
#  'divide',
#  'two',
#  'hydrostatics',
#  'hydraulics',
#  'hydrostatics',
#  'comprehends',
#  'pressure',
#  'equilibrium',
#  'cohesion',
#  'fluid',
#  'motion',
#  'together',
#  'machine',
#  'chiefly',
#  'concerned',
#  'history',
#  'science',
#  'hydrodynamics',
#  'cultivate',
#  'le',
#  'success',
#  'ancient',
#  'mechanical',
#  'philosophy',
#  'human',
#  'mind',
#  'make',
#  'considerable',
#  'progress',
#  'department',
#  'physical',
#  'science',
#  'doctrine',
#  'fluid',
#  'begin',
#  'occupy',
#  'attention',
#  'philosopher',
#  'except',
#  'pressure',
#  'equilibrium',
#  'water',
#  'must',
#  'regard',
#  'modern',
#  'science',
#  'owes',
#  'existence',
#  'improvement',
#  'great',
#  'men',
#  'adorn',
#  'seventeenth',
#  'eighteenth',
#  'century',
#  'discoveries',
#  'general',
#  'principle',
#  'hydrostatics',
#  'day',
#  'employ',
#  'foundation',
#  'part',
#  'science',
#  'first',
#  'give',
#  'archimedes',
#  'work',
#  'a',
#  'c',
#  'h',
#  'de',
#  'year',
#  'fore',
#  'birth',
#  'christ',
#  'afterwards',
#  'apply',
#  'ex',
#  'archimedes',
#  'hi',
#  'archimedes',
#  'maintain',
#  'particle',
#  'fluid',
#  'mass',
#  'equally',
#  'press',
#  'every',
#  'direction',
#  'inquire',
#  'condition',
#  'accord',
#  'solid',
#  'body',
#  'float',
#  'fluid',
#  'assume',
#  'preserve',
#  'position',
#  'equilibrium',
#  'also',
#  'philosopher',
#  'syracuse',
#  'ingenious',
#  'xii',
#  'hydrostatic',
#  'process',
#  'purity',
#  'precious',
#  'history',
#  'metal',
#  'ascertain',
#  'screw',
#  'engine',
#  'v',
#  'go',
#  'name',
#  'theory',
#  'lately',
#  'exer',
#  'ingenuity',
#  'greatest',
#  'in',
#  'greek',
#  'school',
#  'alexandria',
#  'flourish',
#  'auspex',
#  'ptolemy',
#  'first',
#  'attempt',
#  'make',
#  'construction',
#  'hydraulic',
#  'machinery',
#  'about',
#  'year',
#  'birth',
#  'christ',
#  'fountain',
#  'invention',
#  'compression',
#  'syphon',
#  'force',
#  'pump',
#  'vent',
#  'hero',
#  'though',
#  'machine',
#  'operate',
#  'elasticity',
#  'weight',
#  'air',
#  'yet',
#  'inventor',
#  'distinct',
#  'notion',
#  'branch',
#  'science',
#  'syphon',
#  'simple',
#  'instrument',
#  'employ',
#  'empty',
#  'vessel',
#  'full',
#  'water',
#  'spirituous',
#  'liquor',
#  'great',
#  'utility',
#  'art',
#  'force',
#  'pump',
#  'contrary',
#  'complicate',
#  'force',
#  'abstruse',
#  'invention',
#  'scarcely',
#  'un',
#  'expect',
#  'infancy',
#  'hydraulics',
#  'it',
#  'probably',
#  'suggest',
#  'egyptian',
#  'wheel',
#  'noria',
#  'egyptian',
#  'common',
#  'time',
#  'kind',
#  'wheel',
#  'chain',
#  'pump',
#  'consist',
#  'number',
#  'pot',
#  'car',
#  'round',
#  'wheel',
#  'in',
#  'machine',
#  'pot',
#  'valve',
#  'bottom',
#  'enables',
#  'descend',
#  'much',
#  'resistance',
#  'diminishes',
#  'greatly',
#  'load',
#  'wheel',
#  'suppose',
#  'valve',
#  'introduce',
#  'early',
#  'time',
#  'difficult',
#  'perceive',
#  'machine',
#  'might',
#  'lead',
#  'philosopher',
#  'invention',
#  'force',
#  'notwithstanding',
#  'invention',
#  'alexandrian',
#  'labour',
#  'school',
#  'attention',
#  'seem',
#  'direct',
#  'u',
#  'motion',
#  'fluid',
#  'first',
#  'attempt',
#  'investigate',
#  'nu',
#  'subject',
#  'make',
#  'u',
#  'tor',
#  'public',
#  'fountains',
#  'rome',
#  'reign',
#  'nerva',
#  'd',
#  'trajan',
#  'may',
#  'justly',
#  'suppose',
#  'work',
#  'en',
#  'title',
#  'de',
#  'con',
#  'hydraulic',
#  'knowledge',
#  'ancient',
#  'after',
#  'hydrodynamics',
#  'ro',
#  'man',
#  'ac',
#  'art',
#  'con',
#  'water',
#  'pipe',
#  'history',
#  'describe',
#  'nine',
#  'great',
#  'roman',
#  'aqueduct',
#  'v',
#  'add',
#  'mention',
#  'date',
#  'erection',
#  'considers',
#  'method',
#  'time',
#  'employ',
#  'ascertain',
#  'quantity',
#  'water',
#  'discharge',
#  'mode',
#  'distribute',
#  'water',
#  'aqueduct',
#  'fountain',
#  'he',
#  'justly',
#  'remark',
#  'expense',
#  'water',
#  'orifice',
#  'depend',
#  'magnitude',
#  'orifice',
#  'also',
#  'height',
#  'water',
#  'reservoir',
#  'pipe',
#  'employ',
#  'carry',
#  'portion',
#  'water',
#  'aqueduct',
#  'circumstance',
#  'require',
#  'position',
#  'less',
#  'original',
#  'direction',
#  'current',
#  'but',
#  'unacquainted',
#  'true',
#  'law',
#  'velocity',
#  'run',
#  'water',
#  'depend',
#  'depth',
#  'orifice',
#  'scarcely',
#  'surprise',
#  'want',
#  'precision',
#  'appear',
#  'result',
#  'it',
#  'generally',
#  'suppose',
#  'roman',
#  'ignorant',
#  'art',
#  'conduct',
#  'raise',
#  'water',
#  'mean',
#  'pipe',
#  'scarcely',
#  'doubt',
#  'statement',
#  'pliny',
#  'author',
#  'acquaint',
#  'principle',
#  'actually',
#  'use',
#  'leaden',
#  'pipe',
#  'purpose',
#  'pliny',
#  'asserts',
#  'water',
#  'always',
#  'rise',
#  'height',
#  'source',
#  'also',
#  'add',
#  'order',
#  'raise',
#  'water',
#  'leaden',
#  'pipe',
#  'must',
#  'employ',
#  'labour',
#  'ancient',
#  'science',
#  'dynamic',
#  'terminate',
#  'life',
#  'science',
#  'already',
#  'begin',
#  'decline',
#  'night',
#  'ignorance',
#  'barbarism',
#  'advance',
#  'apace',
#  'thousand',
#  'year',
#  'brood',
#  'nation',
#  'europe',
#  'lengthened',
#  'period',
#  'mental',
#  'less',
#  'abstruse',
#  'study',
#  'cease',
#  'attract',
#  'rouse',
#  'energy',
#  'men',
#  'human',
#  'mind',
#  'suppose',
#  'capable',
#  'vigorous',
#  'exertion',
#  'patient',
#  'industry',
#  'indispensable',
#  'physical',
#  'labour',
#  'search',
#  'poetry',
#  'fine',
#  'art',
#  'accordingly',
#  'make',
#  'galileo',
#  'considerable',
#  'progress',
#  'patronage',
#  'family',
#  'bear',
#  'medici',
#  'galileo',
#  'begin',
#  'extend',
#  'boundary',
#  'die',
#  'great',
#  'man',
#  'deserve',
#  'call',
#  'father',
#  'restorer',
#  'physic',
#  'appear',
#  'attention',
#  'doctrine',
#  'fluid',
#  'dis',
#  'uniform',
#  'acceleration',
#  'gravity',
#  'lay',
#  'future',
#  'progress',
#  'contribute',
#  'small',
#  'degree',
#  'aid',
#  'exertion',
#  'genius',
#  'several',
#  'branch',
#  'science',
#  'torricelli',
#  'two',
#  'disciple',
#  'galileo',
#  'bear',
#  'applied',
#  'discovery',
#  'master',
#  'science',
#  'die',
#  'hydrodynamics',
#  'in',
#  'publish',
#  'small',
#  'work',
#  'dell',
#  'give',
#  'satisfactory',
#  'explanation',
#  'several',
#  'phenomenon',
#  'motion',
#  'fluid',
#  'river',
#  'canal',
#  'but',
#  'commit',
#  'great',
#  'paralogism',
#  'suppose',
#  'velocity',
#  'water',
#  'depth',
#  'orifice',
#  'surface',
#  'vessel',
#  'torricelli',
#  'observe',
#  'jet',
#  'water',
#  'push',
#  'small',
#  'rise',
#  'nearly',
#  'same',
#  'reservoir',
#  'sup',
#  'te',
#  'ply',
#  'imagined',
#  'move',
#  'city',
#  'fall',
#  'height',
#  'force',
#  'gravity',
#  'hence',
#  'deduce',
#  'beautiful',
#  'proposition',
#  'velocity',
#  'fluid',
#  'square',
#  'root',
#  'pressure',
#  'abstract',
#  'resist',
#  'air',
#  'friction',
#  'orifice',
#  'rem',
#  'publish',
#  'end',
#  'treatise',
#  'de',
#  'it',
#  'afterwards',
#  'confirm',
#  'experiment',
#  'raphael',
#  'quantity',
#  'water',
#  'discharge',
#  'different',
#  'history',
#  'different',
#  'pressure',
#  'though',
#  'true',
#  'small',
#  'orifice',
#  'give',
#  'new',
#  'turn',
#  'science',
#  'hydraulics',
#  'after',
#  'death',
#  'celebrate',
#  'pascal',
#  'dis',
#  'pascal',
#  'covered',
#  'pressure',
#  'atmosphere',
#  'treatise',
#  'born',
#  'equilibrium',
#  'fluid',
#  'sur',
#  'de',
#  'liqueur',
#  'find',
#  'manuscript',
#  'give',
#  'public',
#  'in',
#  'hand',
#  'pascal',
#  'hydrostatics',
#  'assume',
#  'dignity',
#  'science',
#  'law',
#  'equilibrium',
#  'fluid',
#  'demonstrate',
#  'perspicuous',
#  'manner',
#  'amply',
#  'confirm',
#  'experiment',
#  'discovery',
#  'torricelli',
#  'may',
#  'suppose',
#  'incite',
#  'pascal',
#  'study',
#  'hydraulics',
#  'but',
#  'treat',
#  'subject',
#  'work',
#  'men',
#  'probably',
#  'compose',
#  'discovery',
#  'make',
#  'public',
#  'theorem',
#  'torricelli',
#  'employ',
#  'succeed',
#  'writer',
#  'particularly',
#  'celebrate',
#  'ma',
#  'labour',
#  'department',
#  'physic',
#  'deserve',
#  'die',
#  'recorded',
#  'de',
#  'publish',
#  'death',
#  'year',
#  'found',
#  'great',
#  'variety',
#  'well',
#  'conduct',
#  'experiment',
#  'motion',
#  'fluid',
#  'perform',
#  'versailles',
#  'in',
#  'discussion',
#  'point',
#  'commit',
#  'considerable',
#  'mistake',
#  'treat',
#  'superficially',
#  'none',
#  'experiment',
#  'seem',
#  'attend',
#  'diminution',
#  'efflux',
#  'arise',
#  'contraction',
#  'fluid',
#  'vein',
#  'orifice',
#  'merely',
#  'perforation',
#  'thin',
#  'plate',
#  'appear',
#  'first',
#  'attempt',
#  'ascribe',
#  'discrepancy',
#  'theory',
#  'experiment',
#  'retardation',
#  'water',
#  'velocity',
#  'arise',
#  'inspector',
#  'river',
#  'canal',
#  'milanese',
#  'ascribed',
#  'velocity',
#  'river',
#  'transverse',
#  'motion',
#  'arise',
#  'inequality',
#  'bottom',
#  'but',
#  'ob',
#  'serve',
#  'similar',
#  'obstruction',
#  'even',
#  'glass',
#  'pipe',
#  'transverse',
#  'current',
#  'exist',
#  'cause',
#  'assign',
#  'seem',
#  'destitute',
#  'foundation',
#  'french',
#  'philosopher',
#  'therefore',
#  'regarded',
#  'obstruction',
#  'effect',
#  'friction',
#  'he',
#  'suppose',
#  'filament',
#  'water',
#  'graze',
#  'along',
#  'side',
#  'pipe',
#  'lose',
#  'portion',
#  'velocity',
#  'contiguous',
#  'filament',
#  'account',
#  'greater',
#  'velocity',
#  'rub',
#  'former',
#  'suffer',
#  'diminution',
#  'celerity',
#  'filament',
#  'affect',
#  'similar',
#  'retardation',
#  'proportional',
#  'distance',
#  'axis',
#  'pipe',
#  'in',
#  'way',
#  'medium',
#  'velocity',
#  'current',
#  'may',
#  'diminish',
#  'consequent',
#  'quantity',
#  'water',
#  'discharge',
#  'give',
#  'time',
#  'must',
#  'effect',
#  'friction',
#  'considerably',
#  'less',
#  'computed',
#  'theory',
#  'part',
#  'science',
#  'hydrodynamics',
#  'mo',
#  'relate',
#  'motion',
#  'river',
#  'seem',
#  'originated',
#  'italy',
#  'fertile',
#  'country',
#  'receive',
#  'apennines',
#  'first',
#  'great',
#  'number',
#  'torrent',
#  'traverse',
#  'several',
#  'tend',
#  'mingle',
#  'water',
#  'po',
#  'greater',
#  'part',
#  'fall',
#  'defend',
#  'inundation',
#  'threaten',
#  'become',
#  'necessary',
#  'inhabitant',
#  'change',
#  'course',
#  'river',
#  'thus',
#  'drive',
#  'territory',
#  'let',
#  'loose',
#  'neighbour',
#  'hence',
#  'arise',
#  'continual',
#  'quarrel',
#  'rag',
#  'inhabitant',
#  'ferrara',
#  'attention',
#  'italian',
#  'engineer',
#  'necessarily',
#  'direct',
#  'branch',
#  'science',
#  'cause',
#  'greater',
#  'number',
#  'work',
#  'nine',
#  'aqueduct',
#  'deliver',
#  'every',
#  'day',
#  'cubic',
#  'foot',
#  'water',
#  'cubic',
#  'foot',
#  'consumption',
#  'inhabitant',
#  'suppose',
#  'population',
#  'rome',
#  'million',
#  'accord',
#  'professor',
#  'supply',
#  'modern',
#  'rome',
#  'forty',
#  'cubic',
#  'foot',
#  'person',
#  'london',
#  'three',
#  'cubic',
#  'foot',
#  'paris',
#  'one',
#  'half',
#  'cubic',
#  'foot',
#  'see',
#  'element',
#  'p',
#  'xxxvi',
#  'see',
#  'also',
#  'de',
#  'be',
#  'ix',
#  'c',
#  'horace',
#  'i',
#  'x',
#  'ovid',
#  'meet',
#  'iv',
#  'hydrodynamics',
#  'history',
#  'theory',
#  'mini',
#  'write',
#  'subject',
#  'italy',
#  'rest',
#  'europe',
#  'first',
#  'attend',
#  'mo',
#  'water',
#  'river',
#  'open',
#  'canal',
#  'embrace',
#  'theorem',
#  'torricelli',
#  'confirm',
#  'repeated',
#  'experiment',
#  'conclude',
#  'particle',
#  'perpendicular',
#  'section',
#  'current',
#  'tendency',
#  'move',
#  'velocity',
#  'issue',
#  'orifice',
#  'depth',
#  'surface',
#  'consequence',
#  'deducible',
#  'theory',
#  'run',
#  'water',
#  'every',
#  'respect',
#  'repugnant',
#  'experience',
#  'really',
#  'surprising',
#  'hastily',
#  'adopt',
#  'succeed',
#  'writer',
#  'sufficiently',
#  'sensible',
#  'parabolic',
#  'theory',
#  ...]

# %%
#counting
result = pd.value_counts(seventh_tokens_le) 
result
# Out:
# one           55305
# it            50979
# in            41890
# make          40511
# two           39811
#               ...
# foxglove          1
# porphyra          1
# flashed           1
# unofficial        1
# tanners           1
# Length: 45066, dtype: int64

# %% [markdown]
# After counting the number, I found that there were many unnecessary words, such as one-letter words and two-letter words, and I am now deleting these

# %%
# Filter one-letter words, two-letter words
one_two_letters = [i for i in seventh_tokens_le if len(i) > 2]
three_letters = ['one', 'also', 'per', 'many', 'may', 'two', 'but']
seventh_remain = [i for i in seventh_tokens_le if len(i)>2 and not i in three_letters]

seventh_remain
# Out:
# ['encyclopaedia',
#  'seventh',
#  'edition',
#  'encyclopaedia',
#  'dictionary',
#  'art',
#  'science',
#  'general',
#  'literature',
#  'seventh',
#  'edition',
#  'preliminary',
#  'dissertation',
#  'history',
#  'science',
#  'other',
#  'extensive',
#  'improvement',
#  'addition',
#  'include',
#  'late',
#  'supplement',
#  'general',
#  'index',
#  'numerous',
#  'engraving',
#  'volume',
#  'xii',
#  'adam',
#  'charles',
#  'black',
#  'edinburgh',
#  'xlii',
#  'encyclopedia',
#  'britannic',
#  'hydrodynamics',
#  'history',
#  'water',
#  'power',
#  'properly',
#  'science',
#  'definition',
#  'treat',
#  'power',
#  'water',
#  'act',
#  'pressure',
#  'impulse',
#  'enlarged',
#  'acceptation',
#  'ever',
#  'treat',
#  'pressure',
#  'equilibrium',
#  'cohesion',
#  'motion',
#  'fluid',
#  'machine',
#  'water',
#  'raise',
#  'fluid',
#  'employ',
#  'first',
#  'mover',
#  'hydrodynamics',
#  'divide',
#  'hydrostatics',
#  'hydraulics',
#  'hydrostatics',
#  'comprehends',
#  'pressure',
#  'equilibrium',
#  'cohesion',
#  'fluid',
#  'motion',
#  'together',
#  'machine',
#  'chiefly',
#  'concerned',
#  'history',
#  'science',
#  'hydrodynamics',
#  'cultivate',
#  'success',
#  'ancient',
#  'mechanical',
#  'philosophy',
#  'human',
#  'mind',
#  'make',
#  'considerable',
#  'progress',
#  'department',
#  'physical',
#  'science',
#  'doctrine',
#  'fluid',
#  'begin',
#  'occupy',
#  'attention',
#  'philosopher',
#  'except',
#  'pressure',
#  'equilibrium',
#  'water',
#  'must',
#  'regard',
#  'modern',
#  'science',
#  'owes',
#  'existence',
#  'improvement',
#  'great',
#  'men',
#  'adorn',
#  'seventeenth',
#  'eighteenth',
#  'century',
#  'discoveries',
#  'general',
#  'principle',
#  'hydrostatics',
#  'day',
#  'employ',
#  'foundation',
#  'part',
#  'science',
#  'first',
#  'give',
#  'archimedes',
#  'work',
#  'year',
#  'fore',
#  'birth',
#  'christ',
#  'afterwards',
#  'apply',
#  'archimedes',
#  'archimedes',
#  'maintain',
#  'particle',
#  'fluid',
#  'mass',
#  'equally',
#  'press',
#  'every',
#  'direction',
#  'inquire',
#  'condition',
#  'accord',
#  'solid',
#  'body',
#  'float',
#  'fluid',
#  'assume',
#  'preserve',
#  'position',
#  'equilibrium',
#  'philosopher',
#  'syracuse',
#  'ingenious',
#  'xii',
#  'hydrostatic',
#  'process',
#  'purity',
#  'precious',
#  'history',
#  'metal',
#  'ascertain',
#  'screw',
#  'engine',
#  'name',
#  'theory',
#  'lately',
#  'exer',
#  'ingenuity',
#  'greatest',
#  'greek',
#  'school',
#  'alexandria',
#  'flourish',
#  'auspex',
#  'ptolemy',
#  'first',
#  'attempt',
#  'make',
#  'construction',
#  'hydraulic',
#  'machinery',
#  'about',
#  'year',
#  'birth',
#  'christ',
#  'fountain',
#  'invention',
#  'compression',
#  'syphon',
#  'force',
#  'pump',
#  'vent',
#  'hero',
#  'though',
#  'machine',
#  'operate',
#  'elasticity',
#  'weight',
#  'air',
#  'yet',
#  'inventor',
#  'distinct',
#  'notion',
#  'branch',
#  'science',
#  'syphon',
#  'simple',
#  'instrument',
#  'employ',
#  'empty',
#  'vessel',
#  'full',
#  'water',
#  'spirituous',
#  'liquor',
#  'great',
#  'utility',
#  'art',
#  'force',
#  'pump',
#  'contrary',
#  'complicate',
#  'force',
#  'abstruse',
#  'invention',
#  'scarcely',
#  'expect',
#  'infancy',
#  'hydraulics',
#  'probably',
#  'suggest',
#  'egyptian',
#  'wheel',
#  'noria',
#  'egyptian',
#  'common',
#  'time',
#  'kind',
#  'wheel',
#  'chain',
#  'pump',
#  'consist',
#  'number',
#  'pot',
#  'car',
#  'round',
#  'wheel',
#  'machine',
#  'pot',
#  'valve',
#  'bottom',
#  'enables',
#  'descend',
#  'much',
#  'resistance',
#  'diminishes',
#  'greatly',
#  'load',
#  'wheel',
#  'suppose',
#  'valve',
#  'introduce',
#  'early',
#  'time',
#  'difficult',
#  'perceive',
#  'machine',
#  'might',
#  'lead',
#  'philosopher',
#  'invention',
#  'force',
#  'notwithstanding',
#  'invention',
#  'alexandrian',
#  'labour',
#  'school',
#  'attention',
#  'seem',
#  'direct',
#  'motion',
#  'fluid',
#  'first',
#  'attempt',
#  'investigate',
#  'subject',
#  'make',
#  'tor',
#  'public',
#  'fountains',
#  'rome',
#  'reign',
#  'nerva',
#  'trajan',
#  'justly',
#  'suppose',
#  'work',
#  'title',
#  'con',
#  'hydraulic',
#  'knowledge',
#  'ancient',
#  'after',
#  'hydrodynamics',
#  'man',
#  'art',
#  'con',
#  'water',
#  'pipe',
#  'history',
#  'describe',
#  'nine',
#  'great',
#  'roman',
#  'aqueduct',
#  'add',
#  'mention',
#  'date',
#  'erection',
#  'considers',
#  'method',
#  'time',
#  'employ',
#  'ascertain',
#  'quantity',
#  'water',
#  'discharge',
#  'mode',
#  'distribute',
#  'water',
#  'aqueduct',
#  'fountain',
#  'justly',
#  'remark',
#  'expense',
#  'water',
#  'orifice',
#  'depend',
#  'magnitude',
#  'orifice',
#  'height',
#  'water',
#  'reservoir',
#  'pipe',
#  'employ',
#  'carry',
#  'portion',
#  'water',
#  'aqueduct',
#  'circumstance',
#  'require',
#  'position',
#  'less',
#  'original',
#  'direction',
#  'current',
#  'unacquainted',
#  'true',
#  'law',
#  'velocity',
#  'run',
#  'water',
#  'depend',
#  'depth',
#  'orifice',
#  'scarcely',
#  'surprise',
#  'want',
#  'precision',
#  'appear',
#  'result',
#  'generally',
#  'suppose',
#  'roman',
#  'ignorant',
#  'art',
#  'conduct',
#  'raise',
#  'water',
#  'mean',
#  'pipe',
#  'scarcely',
#  'doubt',
#  'statement',
#  'pliny',
#  'author',
#  'acquaint',
#  'principle',
#  'actually',
#  'use',
#  'leaden',
#  'pipe',
#  'purpose',
#  'pliny',
#  'asserts',
#  'water',
#  'always',
#  'rise',
#  'height',
#  'source',
#  'add',
#  'order',
#  'raise',
#  'water',
#  'leaden',
#  'pipe',
#  'must',
#  'employ',
#  'labour',
#  'ancient',
#  'science',
#  'dynamic',
#  'terminate',
#  'life',
#  'science',
#  'already',
#  'begin',
#  'decline',
#  'night',
#  'ignorance',
#  'barbarism',
#  'advance',
#  'apace',
#  'thousand',
#  'year',
#  'brood',
#  'nation',
#  'europe',
#  'lengthened',
#  'period',
#  'mental',
#  'less',
#  'abstruse',
#  'study',
#  'cease',
#  'attract',
#  'rouse',
#  'energy',
#  'men',
#  'human',
#  'mind',
#  'suppose',
#  'capable',
#  'vigorous',
#  'exertion',
#  'patient',
#  'industry',
#  'indispensable',
#  'physical',
#  'labour',
#  'search',
#  'poetry',
#  'fine',
#  'art',
#  'accordingly',
#  'make',
#  'galileo',
#  'considerable',
#  'progress',
#  'patronage',
#  'family',
#  'bear',
#  'medici',
#  'galileo',
#  'begin',
#  'extend',
#  'boundary',
#  'die',
#  'great',
#  'man',
#  'deserve',
#  'call',
#  'father',
#  'restorer',
#  'physic',
#  'appear',
#  'attention',
#  'doctrine',
#  'fluid',
#  'dis',
#  'uniform',
#  'acceleration',
#  'gravity',
#  'lay',
#  'future',
#  'progress',
#  'contribute',
#  'small',
#  'degree',
#  'aid',
#  'exertion',
#  'genius',
#  'several',
#  'branch',
#  'science',
#  'torricelli',
#  'disciple',
#  'galileo',
#  'bear',
#  'applied',
#  'discovery',
#  'master',
#  'science',
#  'die',
#  'hydrodynamics',
#  'publish',
#  'small',
#  'work',
#  'dell',
#  'give',
#  'satisfactory',
#  'explanation',
#  'several',
#  'phenomenon',
#  'motion',
#  'fluid',
#  'river',
#  'canal',
#  'commit',
#  'great',
#  'paralogism',
#  'suppose',
#  'velocity',
#  'water',
#  'depth',
#  'orifice',
#  'surface',
#  'vessel',
#  'torricelli',
#  'observe',
#  'jet',
#  'water',
#  'push',
#  'small',
#  'rise',
#  'nearly',
#  'same',
#  'reservoir',
#  'sup',
#  'ply',
#  'imagined',
#  'move',
#  'city',
#  'fall',
#  'height',
#  'force',
#  'gravity',
#  'hence',
#  'deduce',
#  'beautiful',
#  'proposition',
#  'velocity',
#  'fluid',
#  'square',
#  'root',
#  'pressure',
#  'abstract',
#  'resist',
#  'air',
#  'friction',
#  'orifice',
#  'rem',
#  'publish',
#  'end',
#  'treatise',
#  'afterwards',
#  'confirm',
#  'experiment',
#  'raphael',
#  'quantity',
#  'water',
#  'discharge',
#  'different',
#  'history',
#  'different',
#  'pressure',
#  'though',
#  'true',
#  'small',
#  'orifice',
#  'give',
#  'new',
#  'turn',
#  'science',
#  'hydraulics',
#  'after',
#  'death',
#  'celebrate',
#  'pascal',
#  'dis',
#  'pascal',
#  'covered',
#  'pressure',
#  'atmosphere',
#  'treatise',
#  'born',
#  'equilibrium',
#  'fluid',
#  'sur',
#  'liqueur',
#  'find',
#  'manuscript',
#  'give',
#  'public',
#  'hand',
#  'pascal',
#  'hydrostatics',
#  'assume',
#  'dignity',
#  'science',
#  'law',
#  'equilibrium',
#  'fluid',
#  'demonstrate',
#  'perspicuous',
#  'manner',
#  'amply',
#  'confirm',
#  'experiment',
#  'discovery',
#  'torricelli',
#  'suppose',
#  'incite',
#  'pascal',
#  'study',
#  'hydraulics',
#  'treat',
#  'subject',
#  'work',
#  'men',
#  'probably',
#  'compose',
#  'discovery',
#  'make',
#  'public',
#  'theorem',
#  'torricelli',
#  'employ',
#  'succeed',
#  'writer',
#  'particularly',
#  'celebrate',
#  'labour',
#  'department',
#  'physic',
#  'deserve',
#  'die',
#  'recorded',
#  'publish',
#  'death',
#  'year',
#  'found',
#  'great',
#  'variety',
#  'well',
#  'conduct',
#  'experiment',
#  'motion',
#  'fluid',
#  'perform',
#  'versailles',
#  'discussion',
#  'point',
#  'commit',
#  'considerable',
#  'mistake',
#  'treat',
#  'superficially',
#  'none',
#  'experiment',
#  'seem',
#  'attend',
#  'diminution',
#  'efflux',
#  'arise',
#  'contraction',
#  'fluid',
#  'vein',
#  'orifice',
#  'merely',
#  'perforation',
#  'thin',
#  'plate',
#  'appear',
#  'first',
#  'attempt',
#  'ascribe',
#  'discrepancy',
#  'theory',
#  'experiment',
#  'retardation',
#  'water',
#  'velocity',
#  'arise',
#  'inspector',
#  'river',
#  'canal',
#  'milanese',
#  'ascribed',
#  'velocity',
#  'river',
#  'transverse',
#  'motion',
#  'arise',
#  'inequality',
#  'bottom',
#  'serve',
#  'similar',
#  'obstruction',
#  'even',
#  'glass',
#  'pipe',
#  'transverse',
#  'current',
#  'exist',
#  'cause',
#  'assign',
#  'seem',
#  'destitute',
#  'foundation',
#  'french',
#  'philosopher',
#  'therefore',
#  'regarded',
#  'obstruction',
#  'effect',
#  'friction',
#  'suppose',
#  'filament',
#  'water',
#  'graze',
#  'along',
#  'side',
#  'pipe',
#  'lose',
#  'portion',
#  'velocity',
#  'contiguous',
#  'filament',
#  'account',
#  'greater',
#  'velocity',
#  'rub',
#  'former',
#  'suffer',
#  'diminution',
#  'celerity',
#  'filament',
#  'affect',
#  'similar',
#  'retardation',
#  'proportional',
#  'distance',
#  'axis',
#  'pipe',
#  'way',
#  'medium',
#  'velocity',
#  'current',
#  'diminish',
#  'consequent',
#  'quantity',
#  'water',
#  'discharge',
#  'give',
#  'time',
#  'must',
#  'effect',
#  'friction',
#  'considerably',
#  'less',
#  'computed',
#  'theory',
#  'part',
#  'science',
#  'hydrodynamics',
#  'relate',
#  'motion',
#  'river',
#  'seem',
#  'originated',
#  'italy',
#  'fertile',
#  'country',
#  'receive',
#  'apennines',
#  'first',
#  'great',
#  'number',
#  'torrent',
#  'traverse',
#  'several',
#  'tend',
#  'mingle',
#  'water',
#  'greater',
#  'part',
#  'fall',
#  'defend',
#  'inundation',
#  'threaten',
#  'become',
#  'necessary',
#  'inhabitant',
#  'change',
#  'course',
#  'river',
#  'thus',
#  'drive',
#  'territory',
#  'let',
#  'loose',
#  'neighbour',
#  'hence',
#  'arise',
#  'continual',
#  'quarrel',
#  'rag',
#  'inhabitant',
#  'ferrara',
#  'attention',
#  'italian',
#  'engineer',
#  'necessarily',
#  'direct',
#  'branch',
#  'science',
#  'cause',
#  'greater',
#  'number',
#  'work',
#  'nine',
#  'aqueduct',
#  'deliver',
#  'every',
#  'day',
#  'cubic',
#  'foot',
#  'water',
#  'cubic',
#  'foot',
#  'consumption',
#  'inhabitant',
#  'suppose',
#  'population',
#  'rome',
#  'million',
#  'accord',
#  'professor',
#  'supply',
#  'modern',
#  'rome',
#  'forty',
#  'cubic',
#  'foot',
#  'person',
#  'london',
#  'three',
#  'cubic',
#  'foot',
#  'paris',
#  'half',
#  'cubic',
#  'foot',
#  'see',
#  'element',
#  'xxxvi',
#  'see',
#  'horace',
#  'ovid',
#  'meet',
#  'hydrodynamics',
#  'history',
#  'theory',
#  'mini',
#  'write',
#  'subject',
#  'italy',
#  'rest',
#  'europe',
#  'first',
#  'attend',
#  'water',
#  'river',
#  'open',
#  'canal',
#  'embrace',
#  'theorem',
#  'torricelli',
#  'confirm',
#  'repeated',
#  'experiment',
#  'conclude',
#  'particle',
#  'perpendicular',
#  'section',
#  'current',
#  'tendency',
#  'move',
#  'velocity',
#  'issue',
#  'orifice',
#  'depth',
#  'surface',
#  'consequence',
#  'deducible',
#  'theory',
#  'run',
#  'water',
#  'every',
#  'respect',
#  'repugnant',
#  'experience',
#  'really',
#  'surprising',
#  'hastily',
#  'adopt',
#  'succeed',
#  'writer',
#  'sufficiently',
#  'sensible',
#  'parabolic',
#  'theory',
#  'contrary',
#  'fact',
#  'reconcile',
#  'suppose',
#  'motion',
#  'river',
#  'obstruct',
#  'transverse',
#  'current',
#  'arise',
#  'bed',
#  'solution',
#  'difficulty',
#  'give',
#  'satisfactory',
#  'ward',
#  'adopt',
#  'maintain',
#  'viscidity',
#  'water',
#  'considerable',
#  'share',
#  'retard',
#  'motion',
#  'effect',
#  'friction',
#  'viscidity',
#  'diminish',
#  'sir',
#  'velocity',
#  'run',
#  'water',
#  'notice',
#  'isaac',
#  'new',
#  'isaac',
#  'newton',
#  'throw',
#  'much',
#  'light',
#  'branch',
#  'hydrodynamics',
#  'die',
#  'system',
#  'vortex',
#  'universally',
#  'prevail',
#  'great',
#  'man',
#  'find',
#  'necessary',
#  'investigate',
#  'absurd',
#  'hypo',
#  'thesis',
#  'course',
#  'investigation',
#  'shew',
#  'velocity',
#  'stratum',
#  'vortex',
#  'metical',
#  'mean',
#  'velocity',
#  'strata',
#  'enclose',
#  'evidently',
#  'follow',
#  'velocity',
#  ...]

# %%
#counting
result = pd.value_counts(seventh_remain) 
result
# Out:
# make          40511
# part          38721
# time          35406
# great         35303
# year          32101
#               ...
# vulgarize         1
# unconfused        1
# oblivious         1
# polska            1
# voided            1
# Length: 44741, dtype: int64

# %%
result.to_csv("words.csv")
